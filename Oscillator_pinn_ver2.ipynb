# %%
import numpy as np
import matplotlib.pyplot as plt
import torch.optim as optim
import torch.nn as nn
import torch
from torch.utils.data import DataLoader
import plotly.graph_objects as go

torch.manual_seed(5)

# %%
class SinActivation(nn.Module):
    def __init__(self):
        super(SinActivation, self).__init__()
        
    def forward(self, x):
        return torch.sin(x)
    
class NeuralNet(nn.Module):

    def __init__(self, input_dimension, output_dimension, n_hidden_layers, neurons, regularization_param, regularization_exp, retrain_seed):
        super(NeuralNet, self).__init__()
        # Number of input dimensions n
        self.input_dimension = input_dimension
        # Number of output dimensions m
        self.output_dimension = output_dimension
        # Number of neurons per layer
        self.neurons = neurons
        # Number of hidden layers
        self.n_hidden_layers = n_hidden_layers
        # Activation function
        self.activation = SinActivation()
        self.regularization_param = regularization_param
        # Regularization exponent
        self.regularization_exp = regularization_exp
        # Random seed for weight initialization

        self.input_layer = nn.Linear(self.input_dimension, self.neurons)
        self.hidden_layers = nn.ModuleList([nn.Linear(self.neurons, self.neurons) for _ in range(n_hidden_layers - 1)])
        self.output_layer = nn.Linear(self.neurons, self.output_dimension)
        self.retrain_seed = retrain_seed
        # Random Seed for weight initialization
        self.init_xavier()

    def forward(self, x):
        # The forward function performs the set of affine and non-linear transformations defining the network
        # (see equation above)
        x = self.activation(self.input_layer(x))
        for k, l in enumerate(self.hidden_layers):
            x = self.activation(l(x))
        return self.output_layer(x)

    def init_xavier(self):
        torch.manual_seed(self.retrain_seed)

        def init_weights(m):
            if type(m) == nn.Linear and m.weight.requires_grad and m.bias.requires_grad:
                g = nn.init.calculate_gain('tanh')
                torch.nn.init.xavier_uniform_(m.weight, gain=g)
                # torch.nn.init.xavier_normal_(m.weight, gain=g)
                m.bias.data.fill_(0)

        self.apply(init_weights)

    def regularization(self):
        reg_loss = 0
        for name, param in self.named_parameters():
            if 'weight' in name:
                reg_loss = reg_loss + torch.norm(param, self.regularization_exp)
        return self.regularization_param * reg_loss



class DrivenOscillatorPinns:
    def __init__(self, n_int_):
        self.n_int = n_int_


        # Initial condition to solve driven oscillator
        self.initial_x = 0
        self.initial_v = 0
        self.init_cond = torch.tensor([self.initial_x,self.initial_v])
        
        self.k = 50
        self.mass = .5

        self.omega_d = 9.95
        self.phid = 1 
        
        self.c = 0.01
        self.F_o = 50
        
        self.initial_weight  = 1
        self.residual_weight = 5
        self.trivial_killer_weight = 1
        
        # Extrema of the solution domain (t) in [0,5]
        self.domain_extrema = torch.tensor([[0, 25]])  
        
        # Generator of Sobol sequences
        self.soboleng = torch.quasirandom.SobolEngine(dimension=1)
        

        self.training_set_int = self.assemble_datasets()

        # F Dense NN to approximate the solution of the underlying heat equation
        self.approximate_solution = NeuralNet(input_dimension=self.domain_extrema.shape[0], output_dimension=1,
                                            n_hidden_layers=3,
                                            neurons=32,
                                            regularization_param=0.,
                                            regularization_exp=0.,
                                            retrain_seed=5)
        
        
    def driven_oscillator(self,t):
        w0 = np.sqrt(self.k/self.mass)
        gamma = self.c/2/self.mass
        
        wprime = np.sqrt(w0**2 - gamma**2)
        print(f"wprime = {wprime}")
        A = self.F_o / self.mass / np.sqrt((w0**2 - self.omega_d**2)**2 + 4 * gamma**2 * self.omega_d**2 )
        
        print(self.k, self.mass, self.omega_d**2)
        phi = np.arctan(self.c * self.omega_d / (self.k - self.mass * self.omega_d**2)) - self.phid
        phih = np.arctan(wprime * (self.initial_x - A * np.cos(phi)) / (self.initial_v + gamma * (self.initial_x - A * np.cos(phi)) - A * self.omega_d * np.sin(phi) ) )
        
        Ah = (self.initial_x - A * np.cos(phi)) / np.sin(phih)
        
        x = Ah * np.exp(-gamma * t) * np.sin(wprime * t + phih) + A * np.cos(self.omega_d * t - phi)
        
        return x

    ################################################################################################
    # Function to linearly transform a tensor whose value are between 0 and 1
    # to a tensor whose values are between the domain extrema
    def convert(self, tens):
        assert (tens.shape[1] == self.domain_extrema.shape[0])
        return tens * (self.domain_extrema[0][1] - self.domain_extrema[0][0]) + self.domain_extrema[0][0]

    def driving_term(self, t):
        return self.F_o*torch.cos(self.omega_d*t + self.phid)
    
    def exact_solution(self, t):
        return
    
    def add_interior_points(self):
        input_int = self.convert(self.soboleng.draw(self.n_int))
        output_int = torch.zeros((input_int.shape[0], 1))
        return input_int, output_int

    # Function returning the training sets S_sb, S_tb, S_int as dataloader
    def assemble_datasets(self):
        input_int, output_int = self.add_interior_points()         # S_int
        training_set_int = DataLoader(torch.utils.data.TensorDataset(input_int, output_int), batch_size=self.n_int, shuffle=False)

        return training_set_int
    

    ################################################################################################
    # Function to compute the terms required in the definition of the TEMPORAL boundary residual
    def initial_velocity(self,init_t):
        init_t.requires_grad = True
        pred_x_init = self.approximate_solution(init_t)
        pred_v_init = torch.autograd.grad(pred_x_init.sum(), init_t, create_graph=True)[0]
        
        return pred_v_init
    
    def initial_position(self,init_t):

        pred_x_init = self.approximate_solution(init_t)
        
        return pred_x_init

    # Function to compute the PDE residuals
    def compute_pde_residual(self, input_int):
        input_int.requires_grad = True
        u = self.approximate_solution(input_int)

        # grad compute the gradient of a "SCALAR" function L with respect to some input nxm TENSOR Z=[[x1, y1],[x2,y2],[x3,y3],...,[xn,yn]], m=2
        # it returns grad_L = [[dL/dx1, dL/dy1],[dL/dx2, dL/dy2],[dL/dx3, dL/dy3],...,[dL/dxn, dL/dyn]]
        # Note: pytorch considers a tensor [u1, u2,u3, ... ,un] a vectorial function
        # whereas sum_u = u1 + u2 + u3 + u4 + ... + un as a "scalar" one

        # In our case ui = u(xi), therefore the line below returns:
        # grad_u = [[dsum_u/dx1, dsum_u/dy1],[dsum_u/dx2, dsum_u/dy2],[dsum_u/dx3, dL/dy3],...,[dsum_u/dxm, dsum_u/dyn]]
        # and dsum_u/dxi = d(u1 + u2 + u3 + u4 + ... + un)/dxi = d(u(x1) + u(x2) u3(x3) + u4(x4) + ... + u(xn))/dxi = dui/dxi
        grad_u_t = torch.autograd.grad(u.sum(), input_int, create_graph=True)[0]
        grad_u_tt = torch.autograd.grad(grad_u_t.sum(), input_int, create_graph=True)[0]

        #grad_u_sq_x = torch.autograd.grad(u_sq.sum(), input_int, create_graph=True)[0][:,1]

        residual = self.mass * grad_u_tt  + self.k*u # - self.driving_term(input_int) + self.gamma*grad_u_t
        return residual.reshape(-1, )

    # Function to compute the total loss (weighted sum of spatial boundary loss, temporal boundary loss and interior loss)
    def compute_loss(self, inp_train_int ,verbose=True):
        
        init_t = torch.zeros(1)
        pred_init_position = self.initial_position(init_t)
        pred_init_velocity = self.initial_velocity(init_t)
        

        # assert (u_pred_tb.shape[0] == self.init_cond.shape[0])

        inp_train_int.requires_grad = True
        u = self.approximate_solution(inp_train_int)

        grad_u_t = torch.autograd.grad(u.sum(), inp_train_int, create_graph=True)[0]
        grad_u_tt = torch.autograd.grad(grad_u_t.sum(), inp_train_int, create_graph=True)[0]


        residual = self.mass*grad_u_tt + self.c*grad_u_t + self.k*u  - self.driving_term(inp_train_int) 
        
        
        init_position_error = self.init_cond[0] - pred_init_position
        init_velocity_error = self.init_cond[1] - pred_init_velocity
        
        loss_initial_position = torch.mean(init_position_error ** 2)
        loss_initial_velocity = torch.mean(init_velocity_error ** 2)

        loss_int = torch.mean(residual ** 2) 
        loss_tb = loss_initial_position + loss_initial_velocity
        loss_trivial = 0
        # loss_trivial = (torch.reciprocal(torch.mean(u**2)) + torch.reciprocal(torch.mean(grad_u_t**2)) + torch.reciprocal(torch.mean(grad_u_tt**2)))*self.trivial_killer_weight
        loss = torch.log10(loss_tb * self.initial_weight  + loss_int * self.residual_weight) #+ loss_trivial
        
        if verbose: print("Total loss: ", round(loss.item(), 8), 
                        "| PDE Loss: ", round(loss_int.item(), 8), 
                        "| Initial Loss: ", round(loss_tb.item(), 8),)
                        #"| Trivial Loss: ", round(loss_trivial.item(), 8))

        return loss 

    ################################################################################################
    def fit(self, num_epochs, optimizer, verbose=True):
        history = list()

        #  prograssive training
        # for fuck in np.linspace(0,25,5):
        #     self.domain_extrema = torch.tensor([[0, fuck]])  
        #     self.training_set_int = self.assemble_datasets()
        # Loop over epochs
        for epoch in range(num_epochs):
            if verbose: print("################################ ", epoch, " ################################")
            
            for j, (inp_train_int, u_train_int) in enumerate(self.training_set_int):
                def closure():
                    optimizer.zero_grad()
                    loss = self.compute_loss(inp_train_int ,verbose=verbose)
                    loss.backward()
                    
                    history.append(loss.item())
                    return loss

                optimizer.step(closure=closure)

        print('Mnimum Loss: ', min(history))

        return history

# %%
n_int = 1000
pinn = DrivenOscillatorPinns(n_int)

# %%
input_int_, output_int_ = pinn.add_interior_points()

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(x=input_int_[:,0], y=output_int_[:,0], mode='markers',marker=dict(color='red',size=1), name='Interior points'))
fig.show()

# %%
# optimizer_LBFGS = optim.LBFGS(pinn.approximate_solution.parameters(),
#                             lr=float(0.001),
#                             max_iter=50000,
#                             max_eval=50000,
#                             history_size=150,
#                             line_search_fn="strong_wolfe",
#                               tolerance_change=1.0 * np.finfo(float).eps)

# %%
hist = []

# %%
optimizer_ADAM = optim.Adam(pinn.approximate_solution.parameters(),
                            lr=float(0.00001))

pinn.initial_weight        = 1.0
pinn.residual_weight       = 1.0

hist += pinn.fit(num_epochs=10000,
                optimizer=optimizer_ADAM,
                verbose=True)
# Out:
# ################################  0  ################################
# Total loss:  -0.11740194 | PDE Loss:  0.75082719 | Initial Loss:  0.01230198
# ################################  1  ################################
# Total loss:  0.28801268 | PDE Loss:  1.92860699 | Initial Loss:  0.01233559
# ################################  2  ################################
# Total loss:  -0.05722652 | PDE Loss:  0.86421436 | Initial Loss:  0.01232916
# ################################  3  ################################
# Total loss:  0.03035042 | PDE Loss:  1.05992842 | Initial Loss:  0.01245586
# ################################  4  ################################
# Total loss:  0.10799909 | PDE Loss:  1.26981962 | Initial Loss:  0.01250829
# ################################  5  ################################
# Total loss:  0.01932405 | PDE Loss:  1.0329932 | Initial Loss:  0.01250679
# ################################  6  ################################
# Total loss:  -0.09694337 | PDE Loss:  0.78747582 | Initial Loss:  0.01246276
# ################################  7  ################################
# Total loss:  -0.06754698 | PDE Loss:  0.84358704 | Initial Loss:  0.01237207
# ################################  8  ################################
# Total loss:  -0.00270849 | PDE Loss:  0.9815346 | Initial Loss:  0.01224827
# ################################  9  ################################
# Total loss:  -0.01281206 | PDE Loss:  0.95879114 | Initial Loss:  0.01213892
# ################################  10  ################################
# Total loss:  -0.07253509 | PDE Loss:  0.83411193 | Initial Loss:  0.01207227
# ################################  11  ################################
# Total loss:  -0.10581674 | PDE Loss:  0.77168638 | Initial Loss:  0.01207395
# ################################  12  ################################
# Total loss:  -0.07944491 | PDE Loss:  0.82068431 | Initial Loss:  0.01214325
# ################################  13  ################################
# Total loss:  -0.05387216 | PDE Loss:  0.87109429 | Initial Loss:  0.01224559
# ################################  14  ################################
# Total loss:  -0.06430662 | PDE Loss:  0.85002339 | Initial Loss:  0.01234608
# ################################  15  ################################
# Total loss:  -0.09390921 | PDE Loss:  0.79314381 | Initial Loss:  0.01240302
# ################################  16  ################################
# Total loss:  -0.10615771 | PDE Loss:  0.77076125 | Initial Loss:  0.01238392
# ################################  17  ################################
# Total loss:  -0.09393752 | PDE Loss:  0.79320335 | Initial Loss:  0.01229096
# ################################  18  ################################
# Total loss:  -0.08365018 | PDE Loss:  0.8126443 | Initial Loss:  0.01215789
# ################################  19  ################################
# Total loss:  -0.08961394 | PDE Loss:  0.80153054 | Initial Loss:  0.01202285
# ################################  20  ################################
# Total loss:  -0.10257532 | PDE Loss:  0.77769899 | Initial Loss:  0.01193291
# ################################  21  ################################
# Total loss:  -0.10737269 | PDE Loss:  0.7690419 | Initial Loss:  0.01191542
# ################################  22  ################################
# Total loss:  -0.10336484 | PDE Loss:  0.7762298 | Initial Loss:  0.01196789
# ################################  23  ################################
# Total loss:  -0.10053656 | PDE Loss:  0.78125423 | Initial Loss:  0.01209322
# ################################  24  ################################
# Total loss:  -0.10283004 | PDE Loss:  0.77691197 | Initial Loss:  0.01225695
# ################################  25  ################################
# Total loss:  -0.10705215 | PDE Loss:  0.76910788 | Initial Loss:  0.01242611
# ################################  26  ################################
# Total loss:  -0.10937733 | PDE Loss:  0.76481837 | Initial Loss:  0.0125425
# ################################  27  ################################
# Total loss:  -0.10979638 | PDE Loss:  0.7640295 | Initial Loss:  0.01258167
# ################################  28  ################################
# Total loss:  -0.10959697 | PDE Loss:  0.76444566 | Initial Loss:  0.01252215
# ################################  29  ################################
# Total loss:  -0.10931303 | PDE Loss:  0.76508409 | Initial Loss:  0.01239187
# ################################  30  ################################
# Total loss:  -0.11015681 | PDE Loss:  0.76374489 | Initial Loss:  0.01222198
# ################################  31  ################################
# Total loss:  -0.11221892 | PDE Loss:  0.76022327 | Initial Loss:  0.01206793
# ################################  32  ################################
# Total loss:  -0.11411399 | PDE Loss:  0.75695622 | Initial Loss:  0.01197236
# ################################  33  ################################
# Total loss:  -0.11377115 | PDE Loss:  0.75756258 | Initial Loss:  0.01197327
# ################################  34  ################################
# Total loss:  -0.11234685 | PDE Loss:  0.75999397 | Initial Loss:  0.01206979
# ################################  35  ################################
# Total loss:  -0.11284114 | PDE Loss:  0.75896269 | Initial Loss:  0.01222283
# ################################  36  ################################
# Total loss:  -0.11506999 | PDE Loss:  0.75485796 | Initial Loss:  0.01237991
# ################################  37  ################################
# Total loss:  -0.11620118 | PDE Loss:  0.75275761 | Initial Loss:  0.0124844
# ################################  38  ################################
# Total loss:  -0.1152961 | PDE Loss:  0.75432926 | Initial Loss:  0.01250921
# ################################  39  ################################
# Total loss:  -0.11442665 | PDE Loss:  0.7559126 | Initial Loss:  0.01246261
# ################################  40  ################################
# Total loss:  -0.11539727 | PDE Loss:  0.75430077 | Initial Loss:  0.01235905
# ################################  41  ################################
# Total loss:  -0.11681443 | PDE Loss:  0.75192261 | Initial Loss:  0.01223964
# ################################  42  ################################
# Total loss:  -0.11678357 | PDE Loss:  0.75206572 | Initial Loss:  0.01215083
# ################################  43  ################################
# Total loss:  -0.11611073 | PDE Loss:  0.75328141 | Initial Loss:  0.01212003
# ################################  44  ################################
# Total loss:  -0.11620513 | PDE Loss:  0.75308704 | Initial Loss:  0.01214801
# ################################  45  ################################
# Total loss:  -0.11706317 | PDE Loss:  0.75150931 | Initial Loss:  0.01221538
# ################################  46  ################################
# Total loss:  -0.1174185 | PDE Loss:  0.75082368 | Initial Loss:  0.01227642
# ################################  47  ################################
# Total loss:  -0.11713459 | PDE Loss:  0.75127512 | Initial Loss:  0.01232399
# ################################  48  ################################
# Total loss:  -0.11704291 | PDE Loss:  0.75144082 | Initial Loss:  0.0123195
# ################################  49  ################################
# Total loss:  -0.11739241 | PDE Loss:  0.75085527 | Initial Loss:  0.01229065
# ################################  50  ################################
# Total loss:  -0.11775422 | PDE Loss:  0.75026405 | Initial Loss:  0.01224635
# ################################  51  ################################
# Total loss:  -0.1177123 | PDE Loss:  0.75036913 | Initial Loss:  0.01221491
# ################################  52  ################################
# Total loss:  -0.11761858 | PDE Loss:  0.75053042 | Initial Loss:  0.01221815
# ################################  53  ################################
# Total loss:  -0.11774498 | PDE Loss:  0.75028241 | Initial Loss:  0.01224423
# ################################  54  ################################
# Total loss:  -0.11795589 | PDE Loss:  0.74988163 | Initial Loss:  0.01227482
# ################################  55  ################################
# Total loss:  -0.11806234 | PDE Loss:  0.74968296 | Initial Loss:  0.01228667
# ################################  56  ################################
# Total loss:  -0.11808378 | PDE Loss:  0.74964494 | Initial Loss:  0.0122871
# ################################  57  ################################
# Total loss:  -0.11805497 | PDE Loss:  0.74971265 | Initial Loss:  0.01226993
# ################################  58  ################################
# Total loss:  -0.11818235 | PDE Loss:  0.74951637 | Initial Loss:  0.01224271
# ################################  59  ################################
# Total loss:  -0.11827608 | PDE Loss:  0.74936938 | Initial Loss:  0.01222534
# ################################  60  ################################
# Total loss:  -0.11834566 | PDE Loss:  0.74924499 | Initial Loss:  0.0122277
# ################################  61  ################################
# Total loss:  -0.11832996 | PDE Loss:  0.74925178 | Initial Loss:  0.01224843
# ################################  62  ################################
# Total loss:  -0.11836011 | PDE Loss:  0.74917501 | Initial Loss:  0.01227239
# ################################  63  ################################
# Total loss:  -0.11843923 | PDE Loss:  0.74902636 | Initial Loss:  0.0122823
# ################################  64  ################################
# Total loss:  -0.11846387 | PDE Loss:  0.74898601 | Initial Loss:  0.01227946
# ################################  65  ################################
# Total loss:  -0.11841379 | PDE Loss:  0.74908727 | Initial Loss:  0.01226597
# ################################  66  ################################
# Total loss:  -0.11846452 | PDE Loss:  0.74901271 | Initial Loss:  0.01225164
# ################################  67  ################################
# Total loss:  -0.11861124 | PDE Loss:  0.74875945 | Initial Loss:  0.01224773
# ################################  68  ################################
# Total loss:  -0.11856396 | PDE Loss:  0.74883348 | Initial Loss:  0.01225655
# ################################  69  ################################
# Total loss:  -0.11854944 | PDE Loss:  0.7488451 | Initial Loss:  0.01227041
# ################################  70  ################################
# Total loss:  -0.1186176 | PDE Loss:  0.74871683 | Initial Loss:  0.01227923
# ################################  71  ################################
# Total loss:  -0.11862818 | PDE Loss:  0.7487039 | Initial Loss:  0.01227362
# ################################  72  ################################
# Total loss:  -0.1186757 | PDE Loss:  0.74862969 | Initial Loss:  0.01226452
# ################################  73  ################################
# Total loss:  -0.1187202 | PDE Loss:  0.74855703 | Initial Loss:  0.01225923
# ################################  74  ################################
# Total loss:  -0.11872997 | PDE Loss:  0.74854457 | Initial Loss:  0.01225462
# ################################  75  ################################
# Total loss:  -0.11872432 | PDE Loss:  0.7485531 | Initial Loss:  0.01225599
# ################################  76  ################################
# Total loss:  -0.11870626 | PDE Loss:  0.74857616 | Initial Loss:  0.01226453
# ################################  77  ################################
# Total loss:  -0.11876635 | PDE Loss:  0.74846047 | Initial Loss:  0.01227497
# ################################  78  ################################
# Total loss:  -0.11880197 | PDE Loss:  0.74840099 | Initial Loss:  0.01227205
# ################################  79  ################################
# Total loss:  -0.11881215 | PDE Loss:  0.74839246 | Initial Loss:  0.01226278
# ################################  80  ################################
# Total loss:  -0.11882566 | PDE Loss:  0.74838072 | Initial Loss:  0.01225087
# ################################  81  ################################
# Total loss:  -0.11879554 | PDE Loss:  0.74843502 | Initial Loss:  0.01224926
# ################################  82  ################################
# Total loss:  -0.11883675 | PDE Loss:  0.74836451 | Initial Loss:  0.0122476
# ################################  83  ################################
# Total loss:  -0.11887198 | PDE Loss:  0.74829602 | Initial Loss:  0.01225442
# ################################  84  ################################
# Total loss:  -0.11884815 | PDE Loss:  0.74832493 | Initial Loss:  0.01226723
# ################################  85  ################################
# Total loss:  -0.1188549 | PDE Loss:  0.74831253 | Initial Loss:  0.01226785
# ################################  86  ################################
# Total loss:  -0.11891139 | PDE Loss:  0.7482118 | Initial Loss:  0.01226962
# ################################  87  ################################
# Total loss:  -0.11889802 | PDE Loss:  0.74823844 | Initial Loss:  0.01226641
# ################################  88  ################################
# Total loss:  -0.11893539 | PDE Loss:  0.7481845 | Initial Loss:  0.01225488
# ################################  89  ################################
# Total loss:  -0.11896164 | PDE Loss:  0.74814302 | Initial Loss:  0.0122504
# ################################  90  ################################
# Total loss:  -0.11894254 | PDE Loss:  0.74817157 | Initial Loss:  0.01225532
# ################################  91  ################################
# Total loss:  -0.11897359 | PDE Loss:  0.74811536 | Initial Loss:  0.01225716
# ################################  92  ################################
# Total loss:  -0.11903988 | PDE Loss:  0.74799192 | Initial Loss:  0.01226455
# ################################  93  ################################
# Total loss:  -0.11900038 | PDE Loss:  0.74806064 | Initial Loss:  0.01226496
# ################################  94  ################################
# Total loss:  -0.11905652 | PDE Loss:  0.7479648 | Initial Loss:  0.01226251
# ################################  95  ################################
# Total loss:  -0.11907451 | PDE Loss:  0.74794239 | Initial Loss:  0.01225345
# ################################  96  ################################
# Total loss:  -0.11910645 | PDE Loss:  0.74789542 | Initial Loss:  0.0122445
# ################################  97  ################################
# Total loss:  -0.11907907 | PDE Loss:  0.74794358 | Initial Loss:  0.01224428
# ################################  98  ################################
# Total loss:  -0.11906729 | PDE Loss:  0.74795926 | Initial Loss:  0.01224921
# ################################  99  ################################
# Total loss:  -0.11908428 | PDE Loss:  0.74792784 | Initial Loss:  0.01225091
# ################################  100  ################################
# Total loss:  -0.11911734 | PDE Loss:  0.74786747 | Initial Loss:  0.01225342
# ################################  101  ################################
# Total loss:  -0.11917704 | PDE Loss:  0.7477622 | Initial Loss:  0.01225417
# ################################  102  ################################
# Total loss:  -0.1192014 | PDE Loss:  0.74771953 | Initial Loss:  0.01225425
# ################################  103  ################################
# Total loss:  -0.11916305 | PDE Loss:  0.74779308 | Initial Loss:  0.01224777
# ################################  104  ################################
# Total loss:  -0.11919367 | PDE Loss:  0.74774444 | Initial Loss:  0.01224286
# ################################  105  ################################
# Total loss:  -0.11919445 | PDE Loss:  0.7477411 | Initial Loss:  0.01224484
# ################################  106  ################################
# Total loss:  -0.11923025 | PDE Loss:  0.74767524 | Initial Loss:  0.01224807
# ################################  107  ################################
# Total loss:  -0.11925685 | PDE Loss:  0.74762833 | Initial Loss:  0.01224842
# ################################  108  ################################
# Total loss:  -0.11924599 | PDE Loss:  0.74764943 | Initial Loss:  0.01224628
# ################################  109  ################################
# Total loss:  -0.1192759 | PDE Loss:  0.7475909 | Initial Loss:  0.0122525
# ################################  110  ################################
# Total loss:  -0.11930796 | PDE Loss:  0.74753982 | Initial Loss:  0.01224753
# ################################  111  ################################
# Total loss:  -0.11929171 | PDE Loss:  0.74757522 | Initial Loss:  0.01224052
# ################################  112  ################################
# Total loss:  -0.11931556 | PDE Loss:  0.74753684 | Initial Loss:  0.01223722
# ################################  113  ################################
# Total loss:  -0.11935331 | PDE Loss:  0.74747175 | Initial Loss:  0.01223622
# ################################  114  ################################
# Total loss:  -0.11934792 | PDE Loss:  0.74748087 | Initial Loss:  0.01223654
# ################################  115  ################################
# Total loss:  -0.11935818 | PDE Loss:  0.74745959 | Initial Loss:  0.01223987
# ################################  116  ################################
# Total loss:  -0.11936605 | PDE Loss:  0.74744135 | Initial Loss:  0.01224433
# ################################  117  ################################
# Total loss:  -0.11938493 | PDE Loss:  0.74740529 | Initial Loss:  0.01224738
# ################################  118  ################################
# Total loss:  -0.11937651 | PDE Loss:  0.74742711 | Initial Loss:  0.01224026
# ################################  119  ################################
# Total loss:  -0.11939365 | PDE Loss:  0.74740344 | Initial Loss:  0.012234
# ################################  120  ################################
# Total loss:  -0.11944627 | PDE Loss:  0.74731886 | Initial Loss:  0.01222651
# ################################  121  ################################
# Total loss:  -0.11949313 | PDE Loss:  0.74723697 | Initial Loss:  0.01222648
# ################################  122  ################################
# Total loss:  -0.11951116 | PDE Loss:  0.7471965 | Initial Loss:  0.01223542
# ################################  123  ################################
# Total loss:  -0.11951601 | PDE Loss:  0.74718225 | Initial Loss:  0.0122412
# ################################  124  ################################
# Total loss:  -0.11954079 | PDE Loss:  0.74714088 | Initial Loss:  0.01223921
# ################################  125  ################################
# Total loss:  -0.11954907 | PDE Loss:  0.74713117 | Initial Loss:  0.01223447
# ################################  126  ################################
# Total loss:  -0.11954477 | PDE Loss:  0.74714565 | Initial Loss:  0.01222746
# ################################  127  ################################
# Total loss:  -0.11956479 | PDE Loss:  0.74711818 | Initial Loss:  0.01221997
# ################################  128  ################################
# Total loss:  -0.11957212 | PDE Loss:  0.74710441 | Initial Loss:  0.01222094
# ################################  129  ################################
# Total loss:  -0.11961995 | PDE Loss:  0.7470147 | Initial Loss:  0.01222697
# ################################  130  ################################
# Total loss:  -0.11958844 | PDE Loss:  0.74707091 | Initial Loss:  0.01222589
# ################################  131  ################################
# Total loss:  -0.11963426 | PDE Loss:  0.74698788 | Initial Loss:  0.0122288
# ################################  132  ################################
# Total loss:  -0.11965094 | PDE Loss:  0.74695873 | Initial Loss:  0.01222881
# ################################  133  ################################
# Total loss:  -0.11964609 | PDE Loss:  0.7469697 | Initial Loss:  0.01222631
# ################################  134  ################################
# Total loss:  -0.11971484 | PDE Loss:  0.74685341 | Initial Loss:  0.01222239
# ################################  135  ################################
# Total loss:  -0.11973906 | PDE Loss:  0.74681312 | Initial Loss:  0.01222038
# ################################  136  ################################
# Total loss:  -0.11973125 | PDE Loss:  0.7468285 | Initial Loss:  0.01221864
# ################################  137  ################################
# Total loss:  -0.11975233 | PDE Loss:  0.74678791 | Initial Loss:  0.01222239
# ################################  138  ################################
# Total loss:  -0.11978619 | PDE Loss:  0.74672157 | Initial Loss:  0.01222959
# ################################  139  ################################
# Total loss:  -0.11981549 | PDE Loss:  0.74667335 | Initial Loss:  0.01222658
# ################################  140  ################################
# Total loss:  -0.11988917 | PDE Loss:  0.74655229 | Initial Loss:  0.01221887
# ################################  141  ################################
# Total loss:  -0.11985199 | PDE Loss:  0.74661803 | Initial Loss:  0.01221809
# ################################  142  ################################
# Total loss:  -0.11984636 | PDE Loss:  0.74663216 | Initial Loss:  0.01221383
# ################################  143  ################################
# Total loss:  -0.11984666 | PDE Loss:  0.74663097 | Initial Loss:  0.01221447
# ################################  144  ################################
# Total loss:  -0.11989491 | PDE Loss:  0.74654645 | Initial Loss:  0.0122147
# ################################  145  ################################
# Total loss:  -0.11987901 | PDE Loss:  0.74657673 | Initial Loss:  0.01221224
# ################################  146  ################################
# Total loss:  -0.11990245 | PDE Loss:  0.746539 | Initial Loss:  0.01220898
# ################################  147  ################################
# Total loss:  -0.11995631 | PDE Loss:  0.74643821 | Initial Loss:  0.01221566
# ################################  148  ################################
# Total loss:  -0.11996048 | PDE Loss:  0.74643213 | Initial Loss:  0.0122145
# ################################  149  ################################
# Total loss:  -0.12000661 | PDE Loss:  0.74635607 | Initial Loss:  0.01220994
# ################################  150  ################################
# Total loss:  -0.11997873 | PDE Loss:  0.74640369 | Initial Loss:  0.01221105
# ################################  151  ################################
# Total loss:  -0.12000576 | PDE Loss:  0.7463631 | Initial Loss:  0.01220443
# ################################  152  ################################
# Total loss:  -0.12002432 | PDE Loss:  0.74633348 | Initial Loss:  0.01220162
# ################################  153  ################################
# Total loss:  -0.12005354 | PDE Loss:  0.74627781 | Initial Loss:  0.01220623
# ################################  154  ################################
# Total loss:  -0.12003203 | PDE Loss:  0.74631697 | Initial Loss:  0.01220463
# ################################  155  ################################
# Total loss:  -0.12003773 | PDE Loss:  0.74630898 | Initial Loss:  0.01220271
# ################################  156  ################################
# Total loss:  -0.12010245 | PDE Loss:  0.74619412 | Initial Loss:  0.01220452
# ################################  157  ################################
# Total loss:  -0.12005999 | PDE Loss:  0.74627119 | Initial Loss:  0.01220162
# ################################  158  ################################
# Total loss:  -0.12014624 | PDE Loss:  0.74611765 | Initial Loss:  0.01220454
# ################################  159  ################################
# Total loss:  -0.12015163 | PDE Loss:  0.74611086 | Initial Loss:  0.01220193
# ################################  160  ################################
# Total loss:  -0.12015253 | PDE Loss:  0.7461133 | Initial Loss:  0.01219789
# ################################  161  ################################
# Total loss:  -0.120163 | PDE Loss:  0.74610233 | Initial Loss:  0.0121906
# ################################  162  ################################
# Total loss:  -0.12013129 | PDE Loss:  0.746153 | Initial Loss:  0.01219529
# ################################  163  ################################
# Total loss:  -0.12011972 | PDE Loss:  0.74617875 | Initial Loss:  0.01218974
# ################################  164  ################################
# Total loss:  -0.12022896 | PDE Loss:  0.74598336 | Initial Loss:  0.01219442
# ################################  165  ################################
# Total loss:  -0.12022227 | PDE Loss:  0.74599034 | Initial Loss:  0.01219907
# ################################  166  ################################
# Total loss:  -0.12026242 | PDE Loss:  0.74592721 | Initial Loss:  0.01219215
# ################################  167  ################################
# Total loss:  -0.12030955 | PDE Loss:  0.74584734 | Initial Loss:  0.01218975
# ################################  168  ################################
# Total loss:  -0.12034021 | PDE Loss:  0.74579334 | Initial Loss:  0.01219019
# ################################  169  ################################
# Total loss:  -0.12038297 | PDE Loss:  0.74571878 | Initial Loss:  0.01219016
# ################################  170  ################################
# Total loss:  -0.12036674 | PDE Loss:  0.74574989 | Initial Loss:  0.01218736
# ################################  171  ################################
# Total loss:  -0.12037569 | PDE Loss:  0.74573952 | Initial Loss:  0.01218211
# ################################  172  ################################
# Total loss:  -0.12038895 | PDE Loss:  0.74571717 | Initial Loss:  0.01218135
# ################################  173  ################################
# Total loss:  -0.12039332 | PDE Loss:  0.74570835 | Initial Loss:  0.01218251
# ################################  174  ################################
# Total loss:  -0.12043407 | PDE Loss:  0.74564111 | Initial Loss:  0.01217865
# ################################  175  ################################
# Total loss:  -0.12037873 | PDE Loss:  0.74573565 | Initial Loss:  0.0121807
# ################################  176  ################################
# Total loss:  -0.1204381 | PDE Loss:  0.74562865 | Initial Loss:  0.01218408
# ################################  177  ################################
# Total loss:  -0.12047797 | PDE Loss:  0.7455644 | Initial Loss:  0.0121788
# ################################  178  ################################
# Total loss:  -0.12049183 | PDE Loss:  0.74554479 | Initial Loss:  0.01217421
# ################################  179  ################################
# Total loss:  -0.12054975 | PDE Loss:  0.74544221 | Initial Loss:  0.01217572
# ################################  180  ################################
# Total loss:  -0.12053344 | PDE Loss:  0.74546808 | Initial Loss:  0.0121783
# ################################  181  ################################
# Total loss:  -0.12055487 | PDE Loss:  0.74542803 | Initial Loss:  0.01218097
# ################################  182  ################################
# Total loss:  -0.12054753 | PDE Loss:  0.74543649 | Initial Loss:  0.01218534
# ################################  183  ################################
# Total loss:  -0.12057394 | PDE Loss:  0.745399 | Initial Loss:  0.01217677
# ################################  184  ################################
# Total loss:  -0.12063152 | PDE Loss:  0.74529755 | Initial Loss:  0.01217777
# ################################  185  ################################
# Total loss:  -0.12067024 | PDE Loss:  0.74523747 | Initial Loss:  0.0121703
# ################################  186  ################################
# Total loss:  -0.12066422 | PDE Loss:  0.745251 | Initial Loss:  0.01216728
# ################################  187  ################################
# Total loss:  -0.12069973 | PDE Loss:  0.74518985 | Initial Loss:  0.01216651
# ################################  188  ################################
# Total loss:  -0.12064293 | PDE Loss:  0.74528891 | Initial Loss:  0.0121665
# ################################  189  ################################
# Total loss:  -0.12068862 | PDE Loss:  0.74520957 | Initial Loss:  0.01216613
# ################################  190  ################################
# Total loss:  -0.12074424 | PDE Loss:  0.74511504 | Initial Loss:  0.01216367
# ################################  191  ################################
# Total loss:  -0.12074659 | PDE Loss:  0.74511403 | Initial Loss:  0.01216057
# ################################  192  ################################
# Total loss:  -0.12075794 | PDE Loss:  0.74509454 | Initial Loss:  0.01216033
# ################################  193  ################################
# Total loss:  -0.12078871 | PDE Loss:  0.74504775 | Initial Loss:  0.01215343
# ################################  194  ################################
# Total loss:  -0.12083483 | PDE Loss:  0.7449674 | Initial Loss:  0.0121534
# ################################  195  ################################
# Total loss:  -0.12081852 | PDE Loss:  0.74499047 | Initial Loss:  0.01215873
# ################################  196  ################################
# Total loss:  -0.12085637 | PDE Loss:  0.7449196 | Initial Loss:  0.01216366
# ################################  197  ################################
# Total loss:  -0.12089285 | PDE Loss:  0.74485987 | Initial Loss:  0.01215978
# ################################  198  ################################
# Total loss:  -0.12090516 | PDE Loss:  0.74483925 | Initial Loss:  0.01215894
# ################################  199  ################################
# Total loss:  -0.12097199 | PDE Loss:  0.74472535 | Initial Loss:  0.01215636
# ################################  200  ################################
# Total loss:  -0.12094583 | PDE Loss:  0.74477267 | Initial Loss:  0.01215465
# ################################  201  ################################
# Total loss:  -0.12102353 | PDE Loss:  0.74464279 | Initial Loss:  0.01214908
# ################################  202  ################################
# Total loss:  -0.12104956 | PDE Loss:  0.74460268 | Initial Loss:  0.01214385
# ################################  203  ################################
# Total loss:  -0.12095417 | PDE Loss:  0.74476033 | Initial Loss:  0.01215241
# ################################  204  ################################
# Total loss:  -0.12099367 | PDE Loss:  0.74469835 | Initial Loss:  0.01214556
# ################################  205  ################################
# Total loss:  -0.12101922 | PDE Loss:  0.74465483 | Initial Loss:  0.01214457
# ################################  206  ################################
# Total loss:  -0.12106024 | PDE Loss:  0.74457759 | Initial Loss:  0.01215033
# ################################  207  ################################
# Total loss:  -0.12110286 | PDE Loss:  0.74451315 | Initial Loss:  0.01214051
# ################################  208  ################################
# Total loss:  -0.12113423 | PDE Loss:  0.74445236 | Initial Loss:  0.01214663
# ################################  209  ################################
# Total loss:  -0.12115993 | PDE Loss:  0.74441242 | Initial Loss:  0.01214184
# ################################  210  ################################
# Total loss:  -0.1211458 | PDE Loss:  0.74444228 | Initial Loss:  0.01213659
# ################################  211  ################################
# Total loss:  -0.12121933 | PDE Loss:  0.74430776 | Initial Loss:  0.01214302
# ################################  212  ################################
# Total loss:  -0.12122792 | PDE Loss:  0.74430436 | Initial Loss:  0.01213146
# ################################  213  ################################
# Total loss:  -0.12125451 | PDE Loss:  0.74424547 | Initial Loss:  0.01214404
# ################################  214  ################################
# Total loss:  -0.12130715 | PDE Loss:  0.74416089 | Initial Loss:  0.01213693
# ################################  215  ################################
# Total loss:  -0.12131526 | PDE Loss:  0.7441538 | Initial Loss:  0.01212992
# ################################  216  ################################
# Total loss:  -0.12130366 | PDE Loss:  0.74417633 | Initial Loss:  0.01212757
# ################################  217  ################################
# Total loss:  -0.12126683 | PDE Loss:  0.74424243 | Initial Loss:  0.01212564
# ################################  218  ################################
# Total loss:  -0.12138951 | PDE Loss:  0.7440269 | Initial Loss:  0.01212753
# ################################  219  ################################
# Total loss:  -0.12135414 | PDE Loss:  0.74409229 | Initial Loss:  0.0121237
# ################################  220  ################################
# Total loss:  -0.12143042 | PDE Loss:  0.74395198 | Initial Loss:  0.01213121
# ################################  221  ################################
# Total loss:  -0.12139704 | PDE Loss:  0.74401361 | Initial Loss:  0.01212767
# ################################  222  ################################
# Total loss:  -0.12146394 | PDE Loss:  0.7438916 | Initial Loss:  0.01213325
# ################################  223  ################################
# Total loss:  -0.12145274 | PDE Loss:  0.74391276 | Initial Loss:  0.01213155
# ################################  224  ################################
# Total loss:  -0.12145384 | PDE Loss:  0.74391216 | Initial Loss:  0.01213027
# ################################  225  ################################
# Total loss:  -0.12152177 | PDE Loss:  0.74379379 | Initial Loss:  0.0121304
# ################################  226  ################################
# Total loss:  -0.12154496 | PDE Loss:  0.74376619 | Initial Loss:  0.01211761
# ################################  227  ################################
# Total loss:  -0.12165421 | PDE Loss:  0.74357581 | Initial Loss:  0.01211788
# ################################  228  ################################
# Total loss:  -0.12160215 | PDE Loss:  0.7436676 | Initial Loss:  0.01211665
# ################################  229  ################################
# Total loss:  -0.12157194 | PDE Loss:  0.74372524 | Initial Loss:  0.01211162
# ################################  230  ################################
# Total loss:  -0.12167189 | PDE Loss:  0.74354291 | Initial Loss:  0.01211999
# ################################  231  ################################
# Total loss:  -0.12169611 | PDE Loss:  0.74351263 | Initial Loss:  0.01210813
# ################################  232  ################################
# Total loss:  -0.12170837 | PDE Loss:  0.74348617 | Initial Loss:  0.01211326
# ################################  233  ################################
# Total loss:  -0.12168442 | PDE Loss:  0.74352986 | Initial Loss:  0.01211125
# ################################  234  ################################
# Total loss:  -0.12171636 | PDE Loss:  0.74347782 | Initial Loss:  0.0121077
# ################################  235  ################################
# Total loss:  -0.12170464 | PDE Loss:  0.74348801 | Initial Loss:  0.01211794
# ################################  236  ################################
# Total loss:  -0.12173674 | PDE Loss:  0.74343348 | Initial Loss:  0.01211661
# ################################  237  ################################
# Total loss:  -0.1217831 | PDE Loss:  0.74335492 | Initial Loss:  0.0121145
# ################################  238  ################################
# Total loss:  -0.12176172 | PDE Loss:  0.74339712 | Initial Loss:  0.01210951
# ################################  239  ################################
# Total loss:  -0.12181404 | PDE Loss:  0.743312 | Initial Loss:  0.01210361
# ################################  240  ################################
# Total loss:  -0.12183494 | PDE Loss:  0.74327844 | Initial Loss:  0.01210083
# ################################  241  ################################
# Total loss:  -0.1218624 | PDE Loss:  0.74323726 | Initial Loss:  0.01209423
# ################################  242  ################################
# Total loss:  -0.12192638 | PDE Loss:  0.74312121 | Initial Loss:  0.01209903
# ################################  243  ################################
# Total loss:  -0.12197094 | PDE Loss:  0.74303752 | Initial Loss:  0.01210523
# ################################  244  ################################
# Total loss:  -0.12195692 | PDE Loss:  0.74306619 | Initial Loss:  0.01210091
# ################################  245  ################################
# Total loss:  -0.12195713 | PDE Loss:  0.74306774 | Initial Loss:  0.012099
# ################################  246  ################################
# Total loss:  -0.12197787 | PDE Loss:  0.74303633 | Initial Loss:  0.01209437
# ################################  247  ################################
# Total loss:  -0.12199998 | PDE Loss:  0.74299467 | Initial Loss:  0.01209762
# ################################  248  ################################
# Total loss:  -0.12205802 | PDE Loss:  0.74289721 | Initial Loss:  0.01209413
# ################################  249  ################################
# Total loss:  -0.1220788 | PDE Loss:  0.74286222 | Initial Loss:  0.01209303
# ################################  250  ################################
# Total loss:  -0.12205343 | PDE Loss:  0.7429058 | Initial Loss:  0.01209353
# ################################  251  ################################
# Total loss:  -0.12201894 | PDE Loss:  0.74298131 | Initial Loss:  0.012078
# ################################  252  ################################
# Total loss:  -0.12208638 | PDE Loss:  0.74284559 | Initial Loss:  0.01209648
# ################################  253  ################################
# Total loss:  -0.12208703 | PDE Loss:  0.7428695 | Initial Loss:  0.01207141
# ################################  254  ################################
# Total loss:  -0.12211083 | PDE Loss:  0.74279994 | Initial Loss:  0.01209964
# ################################  255  ################################
# Total loss:  -0.12212852 | PDE Loss:  0.74279875 | Initial Loss:  0.01207009
# ################################  256  ################################
# Total loss:  -0.12220826 | PDE Loss:  0.74263924 | Initial Loss:  0.01209095
# ################################  257  ################################
# Total loss:  -0.12221941 | PDE Loss:  0.74263668 | Initial Loss:  0.01207419
# ################################  258  ################################
# Total loss:  -0.12226924 | PDE Loss:  0.74254715 | Initial Loss:  0.01207709
# ################################  259  ################################
# Total loss:  -0.12221635 | PDE Loss:  0.74263376 | Initial Loss:  0.0120824
# ################################  260  ################################
# Total loss:  -0.12229285 | PDE Loss:  0.74250501 | Initial Loss:  0.01207825
# ################################  261  ################################
# Total loss:  -0.12230406 | PDE Loss:  0.7424764 | Initial Loss:  0.01208737
# ################################  262  ################################
# Total loss:  -0.12232526 | PDE Loss:  0.74246985 | Initial Loss:  0.01205706
# ################################  263  ################################
# Total loss:  -0.12223951 | PDE Loss:  0.74258637 | Initial Loss:  0.01208957
# ################################  264  ################################
# Total loss:  -0.12222602 | PDE Loss:  0.74265432 | Initial Loss:  0.01204503
# ################################  265  ################################
# Total loss:  -0.12219937 | PDE Loss:  0.74264085 | Initial Loss:  0.01210483
# ################################  266  ################################
# Total loss:  -0.12216847 | PDE Loss:  0.74275345 | Initial Loss:  0.01204591
# ################################  267  ################################
# Total loss:  -0.12212705 | PDE Loss:  0.74276125 | Initial Loss:  0.01211013
# ################################  268  ################################
# Total loss:  -0.12215482 | PDE Loss:  0.74278933 | Initial Loss:  0.01203375
# ################################  269  ################################
# Total loss:  -0.12220891 | PDE Loss:  0.74262905 | Initial Loss:  0.01210007
# ################################  270  ################################
# Total loss:  -0.12244079 | PDE Loss:  0.74228525 | Initial Loss:  0.01204099
# ################################  271  ################################
# Total loss:  -0.12251187 | PDE Loss:  0.74212211 | Initial Loss:  0.0120807
# ################################  272  ################################
# Total loss:  -0.12265395 | PDE Loss:  0.74189162 | Initial Loss:  0.01206444
# ################################  273  ################################
# Total loss:  -0.12270168 | PDE Loss:  0.7418102 | Initial Loss:  0.01206302
# ################################  274  ################################
# Total loss:  -0.12259737 | PDE Loss:  0.74197906 | Initial Loss:  0.01207526
# ################################  275  ################################
# Total loss:  -0.12254564 | PDE Loss:  0.74211204 | Initial Loss:  0.01203211
# ################################  276  ################################
# Total loss:  -0.12253061 | PDE Loss:  0.74209285 | Initial Loss:  0.01207738
# ################################  277  ################################
# Total loss:  -0.12252961 | PDE Loss:  0.74215335 | Initial Loss:  0.0120186
# ################################  278  ################################
# Total loss:  -0.12260493 | PDE Loss:  0.74195939 | Initial Loss:  0.01208179
# ################################  279  ################################
# Total loss:  -0.12263826 | PDE Loss:  0.74194753 | Initial Loss:  0.01203579
# ################################  280  ################################
# Total loss:  -0.12273876 | PDE Loss:  0.74174106 | Initial Loss:  0.01206779
# ################################  281  ################################
# Total loss:  -0.12285087 | PDE Loss:  0.74156868 | Initial Loss:  0.01204565
# ################################  282  ################################
# Total loss:  -0.12290497 | PDE Loss:  0.74147081 | Initial Loss:  0.01204961
# ################################  283  ################################
# Total loss:  -0.12284389 | PDE Loss:  0.74156672 | Initial Loss:  0.01205971
# ################################  284  ################################
# Total loss:  -0.12290256 | PDE Loss:  0.74149019 | Initial Loss:  0.0120344
# ################################  285  ################################
# Total loss:  -0.12285087 | PDE Loss:  0.7415641 | Initial Loss:  0.0120502
# ################################  286  ################################
# Total loss:  -0.12292486 | PDE Loss:  0.74146086 | Initial Loss:  0.01202508
# ################################  287  ################################
# Total loss:  -0.12292527 | PDE Loss:  0.74142861 | Initial Loss:  0.01205658
# ################################  288  ################################
# Total loss:  -0.12295647 | PDE Loss:  0.7414031 | Initial Loss:  0.012028
# ################################  289  ################################
# Total loss:  -0.12299021 | PDE Loss:  0.74131757 | Initial Loss:  0.01205498
# ################################  290  ################################
# Total loss:  -0.12305626 | PDE Loss:  0.74122506 | Initial Loss:  0.01203292
# ################################  291  ################################
# Total loss:  -0.12305739 | PDE Loss:  0.74119765 | Initial Loss:  0.01205838
# ################################  292  ################################
# Total loss:  -0.12298027 | PDE Loss:  0.74136847 | Initial Loss:  0.0120213
# ################################  293  ################################
# Total loss:  -0.12306886 | PDE Loss:  0.74118882 | Initial Loss:  0.01204731
# ################################  294  ################################
# Total loss:  -0.12318968 | PDE Loss:  0.741 | Initial Loss:  0.01202659
# ################################  295  ################################
# Total loss:  -0.12323358 | PDE Loss:  0.7409035 | Initial Loss:  0.01204701
# ################################  296  ################################
# Total loss:  -0.12316342 | PDE Loss:  0.74104172 | Initial Loss:  0.01203042
# ################################  297  ################################
# Total loss:  -0.1232528 | PDE Loss:  0.74088758 | Initial Loss:  0.01202961
# ################################  298  ################################
# Total loss:  -0.12321333 | PDE Loss:  0.74096417 | Initial Loss:  0.01202142
# ################################  299  ################################
# Total loss:  -0.12324829 | PDE Loss:  0.74089962 | Initial Loss:  0.01202534
# ################################  300  ################################
# Total loss:  -0.12325937 | PDE Loss:  0.74087918 | Initial Loss:  0.01202662
# ################################  301  ################################
# Total loss:  -0.1233812 | PDE Loss:  0.74067491 | Initial Loss:  0.01201972
# ################################  302  ################################
# Total loss:  -0.12333553 | PDE Loss:  0.74074703 | Initial Loss:  0.01202673
# ################################  303  ################################
# Total loss:  -0.12335764 | PDE Loss:  0.74072558 | Initial Loss:  0.01200984
# ################################  304  ################################
# Total loss:  -0.12342808 | PDE Loss:  0.74058765 | Initial Loss:  0.01202573
# ################################  305  ################################
# Total loss:  -0.12342566 | PDE Loss:  0.7406106 | Initial Loss:  0.01200695
# ################################  306  ################################
# Total loss:  -0.12342632 | PDE Loss:  0.74059325 | Initial Loss:  0.01202316
# ################################  307  ################################
# Total loss:  -0.12342925 | PDE Loss:  0.74060714 | Initial Loss:  0.0120042
# ################################  308  ################################
# Total loss:  -0.12343423 | PDE Loss:  0.7405749 | Initial Loss:  0.01202783
# ################################  309  ################################
# Total loss:  -0.12349518 | PDE Loss:  0.74049765 | Initial Loss:  0.01199944
# ################################  310  ################################
# Total loss:  -0.1234777 | PDE Loss:  0.74049413 | Initial Loss:  0.01203325
# ################################  311  ################################
# Total loss:  -0.12354042 | PDE Loss:  0.74042606 | Initial Loss:  0.01199262
# ################################  312  ################################
# Total loss:  -0.12348094 | PDE Loss:  0.74048913 | Initial Loss:  0.01203263
# ################################  313  ################################
# Total loss:  -0.12346199 | PDE Loss:  0.74057198 | Initial Loss:  0.01198262
# ################################  314  ################################
# Total loss:  -0.12333776 | PDE Loss:  0.7407313 | Initial Loss:  0.0120386
# ################################  315  ################################
# Total loss:  -0.12338103 | PDE Loss:  0.74072981 | Initial Loss:  0.0119651
# ################################  316  ################################
# Total loss:  -0.12327319 | PDE Loss:  0.74084371 | Initial Loss:  0.01203809
# ################################  317  ################################
# Total loss:  -0.12327456 | PDE Loss:  0.7409206 | Initial Loss:  0.01195885
# ################################  318  ################################
# Total loss:  -0.12323901 | PDE Loss:  0.74091005 | Initial Loss:  0.01203103
# ################################  319  ################################
# Total loss:  -0.12335977 | PDE Loss:  0.74078786 | Initial Loss:  0.01194388
# ################################  320  ################################
# Total loss:  -0.12341555 | PDE Loss:  0.74060386 | Initial Loss:  0.0120312
# ################################  321  ################################
# Total loss:  -0.12359062 | PDE Loss:  0.74036938 | Initial Loss:  0.01196233
# ################################  322  ################################
# Total loss:  -0.12377436 | PDE Loss:  0.7399959 | Initial Loss:  0.0120176
# ################################  323  ################################
# ...
# Total loss:  -0.43789628 | PDE Loss:  0.36211514 | Initial Loss:  0.00272592
# ################################  9894  ################################
# Total loss:  -0.43778628 | PDE Loss:  0.36220446 | Initial Loss:  0.00272904
# ################################  9895  ################################
# Total loss:  -0.43775544 | PDE Loss:  0.36223739 | Initial Loss:  0.00272202
# ################################  9896  ################################
# Total loss:  -0.43763027 | PDE Loss:  0.36233187 | Initial Loss:  0.00273275
# ################################  9897  ################################
# Total loss:  -0.43751058 | PDE Loss:  0.36244085 | Initial Loss:  0.00272439
# ################################  9898  ################################
# Total loss:  -0.43741193 | PDE Loss:  0.36251706 | Initial Loss:  0.00273112
# ################################  9899  ################################
# Total loss:  -0.43732285 | PDE Loss:  0.3626053 | Initial Loss:  0.00271778
# ################################  9900  ################################
# Total loss:  -0.43720451 | PDE Loss:  0.36269149 | Initial Loss:  0.00273117
# ################################  9901  ################################
# Total loss:  -0.43707508 | PDE Loss:  0.36281595 | Initial Loss:  0.00271564
# ################################  9902  ################################
# Total loss:  -0.4369894 | PDE Loss:  0.36287344 | Initial Loss:  0.00273028
# ################################  9903  ################################
# Total loss:  -0.43678695 | PDE Loss:  0.36306143 | Initial Loss:  0.00271275
# ################################  9904  ################################
# Total loss:  -0.43676388 | PDE Loss:  0.36305958 | Initial Loss:  0.00273403
# ################################  9905  ################################
# Total loss:  -0.4367896 | PDE Loss:  0.36305761 | Initial Loss:  0.00271433
# ################################  9906  ################################
# Total loss:  -0.43663543 | PDE Loss:  0.36316416 | Initial Loss:  0.00273767
# ################################  9907  ################################
# Total loss:  -0.43664864 | PDE Loss:  0.36318678 | Initial Loss:  0.00270391
# ################################  9908  ################################
# Total loss:  -0.43653187 | PDE Loss:  0.36324877 | Initial Loss:  0.00274033
# ################################  9909  ################################
# Total loss:  -0.4364166 | PDE Loss:  0.36338443 | Initial Loss:  0.00270181
# ################################  9910  ################################
# Total loss:  -0.43628544 | PDE Loss:  0.36345303 | Initial Loss:  0.00274377
# ################################  9911  ################################
# Total loss:  -0.43642214 | PDE Loss:  0.3633818 | Initial Loss:  0.00269975
# ################################  9912  ################################
# Total loss:  -0.43683243 | PDE Loss:  0.36299953 | Initial Loss:  0.00273637
# ################################  9913  ################################
# Total loss:  -0.43717837 | PDE Loss:  0.36274299 | Initial Loss:  0.00270167
# ################################  9914  ################################
# Total loss:  -0.43772468 | PDE Loss:  0.36225036 | Initial Loss:  0.0027349
# ################################  9915  ################################
# Total loss:  -0.43832451 | PDE Loss:  0.36177197 | Initial Loss:  0.00270953
# ################################  9916  ################################
# Total loss:  -0.43862069 | PDE Loss:  0.36150494 | Initial Loss:  0.00272808
# ################################  9917  ################################
# Total loss:  -0.43895525 | PDE Loss:  0.361238 | Initial Loss:  0.00271455
# ################################  9918  ################################
# Total loss:  -0.43901575 | PDE Loss:  0.36117789 | Initial Loss:  0.00272397
# ################################  9919  ################################
# Total loss:  -0.43908957 | PDE Loss:  0.36112684 | Initial Loss:  0.00271314
# ################################  9920  ################################
# Total loss:  -0.4388316 | PDE Loss:  0.36133307 | Initial Loss:  0.0027231
# ################################  9921  ################################
# Total loss:  -0.43859226 | PDE Loss:  0.36153877 | Initial Loss:  0.00271808
# ################################  9922  ################################
# Total loss:  -0.43837568 | PDE Loss:  0.36172146 | Initial Loss:  0.00271711
# ################################  9923  ################################
# Total loss:  -0.43805808 | PDE Loss:  0.36199597 | Initial Loss:  0.00270921
# ################################  9924  ################################
# Total loss:  -0.43788666 | PDE Loss:  0.36213183 | Initial Loss:  0.00271731
# ################################  9925  ################################
# Total loss:  -0.43786365 | PDE Loss:  0.3621594 | Initial Loss:  0.00270909
# ################################  9926  ################################
# Total loss:  -0.43778878 | PDE Loss:  0.36220965 | Initial Loss:  0.00272172
# ################################  9927  ################################
# Total loss:  -0.43771458 | PDE Loss:  0.36229038 | Initial Loss:  0.00270337
# ################################  9928  ################################
# Total loss:  -0.43778187 | PDE Loss:  0.36220902 | Initial Loss:  0.00272817
# ################################  9929  ################################
# Total loss:  -0.43784997 | PDE Loss:  0.36217612 | Initial Loss:  0.00270384
# ################################  9930  ################################
# Total loss:  -0.43803799 | PDE Loss:  0.36199436 | Initial Loss:  0.00272768
# ################################  9931  ################################
# Total loss:  -0.43805018 | PDE Loss:  0.36201251 | Initial Loss:  0.00269928
# ################################  9932  ################################
# Total loss:  -0.43816131 | PDE Loss:  0.36189154 | Initial Loss:  0.00272694
# ################################  9933  ################################
# Total loss:  -0.43813959 | PDE Loss:  0.36194256 | Initial Loss:  0.00269417
# ################################  9934  ################################
# Total loss:  -0.43823317 | PDE Loss:  0.36182436 | Initial Loss:  0.0027338
# ################################  9935  ################################
# Total loss:  -0.43821293 | PDE Loss:  0.36188537 | Initial Loss:  0.00268976
# ################################  9936  ################################
# Total loss:  -0.4383077 | PDE Loss:  0.36176273 | Initial Loss:  0.00273287
# ################################  9937  ################################
# Total loss:  -0.43840685 | PDE Loss:  0.36172047 | Initial Loss:  0.00269192
# ################################  9938  ################################
# Total loss:  -0.43843105 | PDE Loss:  0.36165774 | Initial Loss:  0.00273435
# ################################  9939  ################################
# Total loss:  -0.43847471 | PDE Loss:  0.36166796 | Initial Loss:  0.00268753
# ################################  9940  ################################
# Total loss:  -0.43843442 | PDE Loss:  0.36165902 | Initial Loss:  0.00273024
# ################################  9941  ################################
# Total loss:  -0.43846926 | PDE Loss:  0.36167088 | Initial Loss:  0.00268914
# ################################  9942  ################################
# Total loss:  -0.43830973 | PDE Loss:  0.36176276 | Initial Loss:  0.00273114
# ################################  9943  ################################
# Total loss:  -0.43821412 | PDE Loss:  0.36188874 | Initial Loss:  0.00268542
# ################################  9944  ################################
# Total loss:  -0.43788478 | PDE Loss:  0.36211991 | Initial Loss:  0.0027308
# ################################  9945  ################################
# Total loss:  -0.4375284 | PDE Loss:  0.36245936 | Initial Loss:  0.00269089
# ################################  9946  ################################
# Total loss:  -0.43723431 | PDE Loss:  0.36266375 | Initial Loss:  0.00273384
# ################################  9947  ################################
# Total loss:  -0.43690103 | PDE Loss:  0.362997 | Initial Loss:  0.00268111
# ################################  9948  ################################
# Total loss:  -0.43641809 | PDE Loss:  0.36335585 | Initial Loss:  0.00272914
# ################################  9949  ################################
# Total loss:  -0.43620041 | PDE Loss:  0.36357996 | Initial Loss:  0.00268856
# ################################  9950  ################################
# Total loss:  -0.43607375 | PDE Loss:  0.3636438 | Initial Loss:  0.00273155
# ################################  9951  ################################
# Total loss:  -0.43660411 | PDE Loss:  0.36323729 | Initial Loss:  0.00269092
# ################################  9952  ################################
# Total loss:  -0.43698505 | PDE Loss:  0.36288911 | Initial Loss:  0.00271826
# ################################  9953  ################################
# Total loss:  -0.4376584 | PDE Loss:  0.36235088 | Initial Loss:  0.00269007
# ################################  9954  ################################
# Total loss:  -0.43845773 | PDE Loss:  0.36165753 | Initial Loss:  0.00271218
# ################################  9955  ################################
# Total loss:  -0.43887526 | PDE Loss:  0.36131716 | Initial Loss:  0.00270241
# ################################  9956  ################################
# Total loss:  -0.4388715 | PDE Loss:  0.36131677 | Initial Loss:  0.00270597
# ################################  9957  ################################
# Total loss:  -0.43882316 | PDE Loss:  0.36135274 | Initial Loss:  0.0027105
# ################################  9958  ################################
# Total loss:  -0.4382239 | PDE Loss:  0.36187264 | Initial Loss:  0.00269331
# ################################  9959  ################################
# Total loss:  -0.43760934 | PDE Loss:  0.36236745 | Initial Loss:  0.00271477
# ################################  9960  ################################
# Total loss:  -0.43711078 | PDE Loss:  0.36281192 | Initial Loss:  0.00268963
# ################################  9961  ################################
# Total loss:  -0.43693963 | PDE Loss:  0.36292964 | Initial Loss:  0.00271599
# ################################  9962  ################################
# Total loss:  -0.43687618 | PDE Loss:  0.36300889 | Initial Loss:  0.00269018
# ################################  9963  ################################
# Total loss:  -0.43718553 | PDE Loss:  0.36272293 | Initial Loss:  0.00271569
# ################################  9964  ################################
# Total loss:  -0.43774506 | PDE Loss:  0.36227575 | Initial Loss:  0.00269238
# ################################  9965  ################################
# Total loss:  -0.43829957 | PDE Loss:  0.36179566 | Initial Loss:  0.00270677
# ################################  9966  ################################
# Total loss:  -0.43889588 | PDE Loss:  0.36130482 | Initial Loss:  0.00269748
# ################################  9967  ################################
# Total loss:  -0.43932953 | PDE Loss:  0.36093581 | Initial Loss:  0.00270318
# ################################  9968  ################################
# Total loss:  -0.43946597 | PDE Loss:  0.3608166 | Initial Loss:  0.00270819
# ################################  9969  ################################
# Total loss:  -0.43954512 | PDE Loss:  0.36076501 | Initial Loss:  0.00269353
# ################################  9970  ################################
# Total loss:  -0.43919522 | PDE Loss:  0.36104071 | Initial Loss:  0.00271079
# ################################  9971  ################################
# Total loss:  -0.43916777 | PDE Loss:  0.36108801 | Initial Loss:  0.00268647
# ################################  9972  ################################
# Total loss:  -0.43899614 | PDE Loss:  0.36120376 | Initial Loss:  0.0027145
# ################################  9973  ################################
# Total loss:  -0.43923056 | PDE Loss:  0.36103603 | Initial Loss:  0.00268583
# ################################  9974  ################################
# Total loss:  -0.43945679 | PDE Loss:  0.3608197 | Initial Loss:  0.00271277
# ################################  9975  ################################
# Total loss:  -0.4397904 | PDE Loss:  0.36056551 | Initial Loss:  0.00268781
# ################################  9976  ################################
# Total loss:  -0.44005728 | PDE Loss:  0.36032262 | Initial Loss:  0.00270754
# ################################  9977  ################################
# Total loss:  -0.44021484 | PDE Loss:  0.36021203 | Initial Loss:  0.00268647
# ################################  9978  ################################
# Total loss:  -0.44041914 | PDE Loss:  0.36002162 | Initial Loss:  0.00270621
# ################################  9979  ################################
# Total loss:  -0.44037947 | PDE Loss:  0.36006671 | Initial Loss:  0.00269426
# ################################  9980  ################################
# Total loss:  -0.44054294 | PDE Loss:  0.35992473 | Initial Loss:  0.00269971
# ################################  9981  ################################
# Total loss:  -0.44045293 | PDE Loss:  0.36000535 | Initial Loss:  0.00269425
# ################################  9982  ################################
# Total loss:  -0.4405489 | PDE Loss:  0.35991961 | Initial Loss:  0.00269984
# ################################  9983  ################################
# Total loss:  -0.44058308 | PDE Loss:  0.35989437 | Initial Loss:  0.00269655
# ################################  9984  ################################
# Total loss:  -0.44061515 | PDE Loss:  0.35986492 | Initial Loss:  0.00269922
# ################################  9985  ################################
# Total loss:  -0.4406015 | PDE Loss:  0.35988018 | Initial Loss:  0.00269536
# ################################  9986  ################################
# Total loss:  -0.44067216 | PDE Loss:  0.35982475 | Initial Loss:  0.00269179
# ################################  9987  ################################
# Total loss:  -0.4405888 | PDE Loss:  0.35989401 | Initial Loss:  0.00269215
# ################################  9988  ################################
# Total loss:  -0.44060886 | PDE Loss:  0.35987949 | Initial Loss:  0.0026899
# ################################  9989  ################################
# Total loss:  -0.44061282 | PDE Loss:  0.35987139 | Initial Loss:  0.00269468
# ################################  9990  ################################
# Total loss:  -0.44051209 | PDE Loss:  0.35995519 | Initial Loss:  0.00269498
# ################################  9991  ################################
# Total loss:  -0.4405143 | PDE Loss:  0.35995489 | Initial Loss:  0.00269344
# ################################  9992  ################################
# Total loss:  -0.44046929 | PDE Loss:  0.35999486 | Initial Loss:  0.00269106
# ################################  9993  ################################
# Total loss:  -0.44047353 | PDE Loss:  0.35998863 | Initial Loss:  0.00269378
# ################################  9994  ################################
# Total loss:  -0.44023505 | PDE Loss:  0.36018968 | Initial Loss:  0.00269194
# ################################  9995  ################################
# Total loss:  -0.43990883 | PDE Loss:  0.36046034 | Initial Loss:  0.00269395
# ################################  9996  ################################
# Total loss:  -0.43968561 | PDE Loss:  0.36064741 | Initial Loss:  0.00269357
# ################################  9997  ################################
# Total loss:  -0.43931681 | PDE Loss:  0.36096096 | Initial Loss:  0.00268869
# ################################  9998  ################################
# Total loss:  -0.43884781 | PDE Loss:  0.36134744 | Initial Loss:  0.00269513
# ################################  9999  ################################
# Total loss:  -0.43836966 | PDE Loss:  0.36175585 | Initial Loss:  0.00268776
# Mnimum Loss:  -0.4406721591949463

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(y=hist))
# set dark theme
fig.update_layout(title='Loss function', xaxis_title='Epoch', yaxis_title='Loss', template='plotly_dark')
fig.show()

# %%
inputs = pinn.soboleng.draw(1000)
inputs = pinn.convert(inputs)
output = pinn.approximate_solution(inputs)

fig = go.Figure()
fig.add_trace(go.Scatter(x=inputs.detach().numpy()[:,0], y=output.detach().numpy()[:,0], mode='markers', name='PINN solution', marker=dict(color='yellow')))
#set marker size
fig.add_trace(go.Scatter(x=inputs.detach().numpy()[:,0], y=pinn.driven_oscillator(inputs).detach().numpy()[:,0], mode='markers', name='Exact solution', marker=dict(color='blue',size=3)))
fig.update_layout(title='Exact solution vs PINN solution', xaxis_title='time', yaxis_title='position', template='plotly_dark')

#fig.write_image('oscillator_pinn.png')
fig.show()
# Out:
# wprime = 9.99999499999875
# 50 0.5 99.00249999999998

# %%
# print initial velocity and position
init_t = torch.zeros(1)
pred_init_position = pinn.initial_position(init_t)
pred_init_velocity = pinn.initial_velocity(init_t)
print("Initial position: ", pred_init_position.item())
print("Initial velocity: ", pred_init_velocity.item())
# Out:
# Initial position:  -0.7104247808456421
# Initial velocity:  -0.06117963790893555
