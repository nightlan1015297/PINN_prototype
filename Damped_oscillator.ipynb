# %%
import numpy as np
import matplotlib.pyplot as plt
import torch.optim as optim
import torch.nn as nn
import torch
from torch.utils.data import DataLoader
import plotly.graph_objects as go

torch.manual_seed(0)

# %%
class NeuralNet(nn.Module):

    def __init__(self, input_dimension, output_dimension, n_hidden_layers, neurons, regularization_param, regularization_exp, retrain_seed):
        super(NeuralNet, self).__init__()
        # Number of input dimensions n
        self.input_dimension = input_dimension
        # Number of output dimensions m
        self.output_dimension = output_dimension
        # Number of neurons per layer
        self.neurons = neurons
        # Number of hidden layers
        self.n_hidden_layers = n_hidden_layers
        # Activation function
        self.activation = nn.Tanh()
        self.regularization_param = regularization_param
        # Regularization exponent
        self.regularization_exp = regularization_exp
        # Random seed for weight initialization

        self.input_layer = nn.Linear(self.input_dimension, self.neurons)
        self.hidden_layers = nn.ModuleList([nn.Linear(self.neurons, self.neurons) for _ in range(n_hidden_layers - 1)])
        self.output_layer = nn.Linear(self.neurons, self.output_dimension)
        self.retrain_seed = retrain_seed
        # Random Seed for weight initialization
        self.init_xavier()

    def forward(self, x):
        # The forward function performs the set of affine and non-linear transformations defining the network
        # (see equation above)
        x = self.activation(self.input_layer(x))
        for k, l in enumerate(self.hidden_layers):
            x = self.activation(l(x))
        return self.output_layer(x)

    def init_xavier(self):
        torch.manual_seed(self.retrain_seed)

        def init_weights(m):
            if type(m) == nn.Linear and m.weight.requires_grad and m.bias.requires_grad:
                g = nn.init.calculate_gain('tanh')
                torch.nn.init.xavier_uniform_(m.weight, gain=g)
                # torch.nn.init.xavier_normal_(m.weight, gain=g)
                m.bias.data.fill_(0)

        self.apply(init_weights)

    def regularization(self):
        reg_loss = 0
        for name, param in self.named_parameters():
            if 'weight' in name:
                reg_loss = reg_loss + torch.norm(param, self.regularization_exp)
        return self.regularization_param * reg_loss

class DrivenOscillatorPinns:
    def __init__(self, n_int_):
        self.n_int = n_int_


        # Initial condition to solve driven oscillator
        self.initial_x = 5
        self.initial_v = 0
        self.init_cond = torch.tensor([self.initial_x,self.initial_v])
        
        
        self.omega_o = 1
        self.omega_d = 1
        self.k = 1
        self.gamma   = 0.01
        self.mass = 1
        self.F_o = 0
        
        self.initial_weight  = 10
        self.residual_weight = 1
        self.trivial_killer_weight = 1
        
        # Extrema of the solution domain (t) in [0,5]
        self.domain_extrema = torch.tensor([[0, 10]])  
        
        # Generator of Sobol sequences
        self.soboleng = torch.quasirandom.SobolEngine(dimension=1)
        

        self.training_set_int = self.assemble_datasets()

        # F Dense NN to approximate the solution of the underlying heat equation
        self.approximate_solution = NeuralNet(input_dimension=self.domain_extrema.shape[0], output_dimension=1,
                                            n_hidden_layers=10,
                                            neurons=200,
                                            regularization_param=0.,
                                            regularization_exp=5,
                                            retrain_seed=20)
        
        

    ################################################################################################
    # Function to linearly transform a tensor whose value are between 0 and 1
    # to a tensor whose values are between the domain extrema
    def convert(self, tens):
        assert (tens.shape[1] == self.domain_extrema.shape[0])
        return tens * (self.domain_extrema[0][1] - self.domain_extrema[0][0]) + self.domain_extrema[0][0]

    def driving_term(self, t):
        return self.F_o*torch.cos(self.omega_d*t)/self.mass
    
    def exact_solution(self, t):
        return
    
    def add_interior_points(self):
        input_int = self.convert(self.soboleng.draw(self.n_int))
        output_int = torch.zeros((input_int.shape[0], 1))
        return input_int, output_int

    # Function returning the training sets S_sb, S_tb, S_int as dataloader
    def assemble_datasets(self):
        input_int, output_int = self.add_interior_points()         # S_int
        training_set_int = DataLoader(torch.utils.data.TensorDataset(input_int, output_int), batch_size=self.n_int, shuffle=False)

        return training_set_int
    

    ################################################################################################
    # Function to compute the terms required in the definition of the TEMPORAL boundary residual
    def initial_velocity(self,init_t):
        init_t.requires_grad = True
        pred_x_init = self.approximate_solution(init_t)
        pred_v_init = torch.autograd.grad(pred_x_init.sum(), init_t, create_graph=True)[0]
        
        return pred_v_init
    
    def initial_position(self,init_t):

        pred_x_init = self.approximate_solution(init_t)
        
        return pred_x_init

    # Function to compute the PDE residuals
    def compute_pde_residual(self, input_int):
        input_int.requires_grad = True
        u = self.approximate_solution(input_int)

        # grad compute the gradient of a "SCALAR" function L with respect to some input nxm TENSOR Z=[[x1, y1],[x2,y2],[x3,y3],...,[xn,yn]], m=2
        # it returns grad_L = [[dL/dx1, dL/dy1],[dL/dx2, dL/dy2],[dL/dx3, dL/dy3],...,[dL/dxn, dL/dyn]]
        # Note: pytorch considers a tensor [u1, u2,u3, ... ,un] a vectorial function
        # whereas sum_u = u1 + u2 + u3 + u4 + ... + un as a "scalar" one

        # In our case ui = u(xi), therefore the line below returns:
        # grad_u = [[dsum_u/dx1, dsum_u/dy1],[dsum_u/dx2, dsum_u/dy2],[dsum_u/dx3, dL/dy3],...,[dsum_u/dxm, dsum_u/dyn]]
        # and dsum_u/dxi = d(u1 + u2 + u3 + u4 + ... + un)/dxi = d(u(x1) + u(x2) u3(x3) + u4(x4) + ... + u(xn))/dxi = dui/dxi
        grad_u_t = torch.autograd.grad(u.sum(), input_int, create_graph=True)[0]
        grad_u_tt = torch.autograd.grad(grad_u_t.sum(), input_int, create_graph=True)[0]

        #grad_u_sq_x = torch.autograd.grad(u_sq.sum(), input_int, create_graph=True)[0][:,1]

        residual = self.mass * grad_u_tt  + self.k*u # - self.driving_term(input_int) + self.gamma*grad_u_t
        return residual.reshape(-1, )

    # Function to compute the total loss (weighted sum of spatial boundary loss, temporal boundary loss and interior loss)
    def compute_loss(self, inp_train_int ,verbose=True):
        
        init_t = torch.zeros(1)
        pred_init_position = self.initial_position(init_t)
        pred_init_velocity = self.initial_velocity(init_t)
        

        inp_train_int.requires_grad = True
        u = self.approximate_solution(inp_train_int)

        grad_u_t = torch.autograd.grad(u.sum(), inp_train_int, create_graph=True)[0]
        grad_u_tt = torch.autograd.grad(grad_u_t.sum(), inp_train_int, create_graph=True)[0]


        residual = self.mass * grad_u_tt  + self.omega_o**2*u  - self.driving_term(inp_train_int) + self.gamma*grad_u_t
        
        
        init_position_error = self.init_cond[0] - pred_init_position
        init_velocity_error = self.init_cond[1] - pred_init_velocity
        
        loss_initial_position = torch.mean(init_position_error ** 2)*self.initial_weight
        loss_initial_velocity = torch.mean(init_velocity_error ** 2)*self.initial_weight

        loss_int = torch.mean(residual ** 2)*self.residual_weight

        loss = loss_initial_position + loss_initial_velocity + loss_int
        
        if verbose: print("Total loss: ", round(loss.item(), 4), "| PDE Loss: ", round(loss_int.item(), 4), "| Position Loss: ", round(loss_initial_position.item(), 4),"| Velocity Loss: ", round(loss_initial_velocity.item(), 4))

        return loss + (torch.reciprocal(torch.mean(u ** 2)) + torch.reciprocal(torch.mean(grad_u_t ** 2)))*self.trivial_killer_weight 

    ################################################################################################
    def fit(self, num_epochs, optimizer, verbose=True):
        history = list()

        # Loop over epochs
        for epoch in range(num_epochs):
            if verbose: print("################################ ", epoch, " ################################")

            
            for j, (inp_train_int, u_train_int) in enumerate(self.training_set_int):
                def closure():
                    optimizer.zero_grad()
                    loss = self.compute_loss(inp_train_int ,verbose=verbose)
                    loss.backward()
                    
                    history.append(loss.item())
                    return loss

                optimizer.step(closure=closure)

        print('Final Loss: ', history[-1])

        return history

# %%
n_int = 1000
pinn = DrivenOscillatorPinns(n_int)
input_int_, output_int_ = pinn.add_interior_points()

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(x=input_int_[:,0], y=output_int_[:,0], mode='markers',marker=dict(color='red',size=1), name='Interior points'))
fig.show()

# %%
optimizer_LBFGS = optim.LBFGS(pinn.approximate_solution.parameters(),
                            lr=float(0.000001),
                            max_iter=50000,
                            max_eval=50000,
                            history_size=150,
                            line_search_fn="strong_wolfe",
                              tolerance_change=1.0 * np.finfo(float).eps)
optimizer_ADAM = optim.Adam(pinn.approximate_solution.parameters(),
                            lr=float(0.0001))

# %%
pinn.trivial_killer_weight = 0.
optimizer_ADAM.lr = 0.000005

hist = pinn.fit(num_epochs=500,
                optimizer=optimizer_LBFGS,
                verbose=True)
# Out:
# ################################  0  ################################
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# ################################  1  ################################
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# ################################  2  ################################
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# ################################  3  ################################
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# ################################  4  ################################
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# ################################  5  ################################
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# ################################  6  ################################
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# ################################  7  ################################
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# ################################  8  ################################
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# ################################  9  ################################
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# ################################  10  ################################
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# ################################  11  ################################
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# ################################  12  ################################
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# ################################  13  ################################
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# ################################  14  ################################
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# ################################  15  ################################
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# ################################  16  ################################
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# ################################  17  ################################
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# ################################  18  ################################
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# ################################  19  ################################
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# ################################  20  ################################
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# ################################  21  ################################
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# ################################  22  ################################
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# ################################  23  ################################
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# ################################  24  ################################
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# ################################  25  ################################
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# ################################  26  ################################
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# ################################  27  ################################
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# ################################  28  ################################
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# ################################  29  ################################
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# ################################  30  ################################
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# ################################  31  ################################
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# ################################  32  ################################
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# ################################  33  ################################
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# ################################  34  ################################
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# ################################  35  ################################
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# ################################  36  ################################
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# ################################  37  ################################
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# ################################  38  ################################
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# ################################  39  ################################
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# ################################  40  ################################
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# ################################  41  ################################
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# ################################  42  ################################
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# ################################  43  ################################
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# ################################  44  ################################
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# ################################  45  ################################
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# ################################  46  ################################
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# ################################  47  ################################
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# ################################  48  ################################
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# ################################  49  ################################
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# ################################  50  ################################
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# ################################  51  ################################
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# ################################  52  ################################
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# ################################  53  ################################
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# ################################  54  ################################
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# ################################  55  ################################
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# ################################  56  ################################
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# ################################  57  ################################
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# ################################  58  ################################
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# ################################  59  ################################
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# ################################  60  ################################
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# ################################  61  ################################
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# ################################  62  ################################
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# ################################  63  ################################
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# ################################  64  ################################
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# ################################  65  ################################
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# ################################  66  ################################
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# ################################  67  ################################
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# ################################  68  ################################
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# ################################  69  ################################
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# ################################  70  ################################
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# ################################  71  ################################
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# ################################  72  ################################
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# ################################  73  ################################
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# ################################  74  ################################
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# ################################  75  ################################
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# ################################  76  ################################
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# ################################  77  ################################
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# ################################  78  ################################
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# ################################  79  ################################
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# ################################  80  ################################
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# ################################  81  ################################
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# ################################  82  ################################
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# ################################  83  ################################
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# ################################  84  ################################
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# ################################  85  ################################
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# ################################  86  ################################
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# ################################  87  ################################
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# ################################  88  ################################
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# ################################  89  ################################
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# ################################  90  ################################
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# ################################  91  ################################
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# ################################  92  ################################
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# ################################  93  ################################
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# ################################  94  ################################
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# ################################  95  ################################
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# ################################  96  ################################
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# ################################  97  ################################
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# ################################  98  ################################
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# ################################  99  ################################
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# ################################  100  ################################
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# ################################  101  ################################
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# ################################  102  ################################
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# ################################  103  ################################
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# ################################  104  ################################
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# ################################  105  ################################
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# ################################  106  ################################
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# ################################  107  ################################
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# ################################  108  ################################
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# ################################  109  ################################
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# ################################  110  ################################
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# ################################  111  ################################
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# ################################  112  ################################
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# ################################  113  ################################
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# ################################  114  ################################
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# ################################  115  ################################
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# ################################  116  ################################
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# ...
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# ################################  254  ################################
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# ################################  255  ################################
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# ################################  256  ################################
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# ################################  257  ################################
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# ################################  258  ################################
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# ################################  259  ################################
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# ################################  260  ################################
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# ################################  261  ################################
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# ################################  262  ################################
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# ################################  263  ################################
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# ################################  264  ################################
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# ################################  265  ################################
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# ################################  266  ################################
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# ################################  267  ################################
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# ################################  268  ################################
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# ################################  269  ################################
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# ################################  270  ################################
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# ################################  271  ################################
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# ################################  272  ################################
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# ################################  273  ################################
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# ################################  274  ################################
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# ################################  275  ################################
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# ################################  276  ################################
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# Total loss:  0.0002 | PDE Loss:  0.0002 | Position Loss:  0.0 | Velocity Loss:  0.0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/dim1112/Desktop/PINN_prototype/Damped_oscillator.ipynb Cell 6 line 4
#       <a href='vscode-notebook-cell:/home/dim1112/Desktop/PINN_prototype/Damped_oscillator.ipynb#W5sZmlsZQ%3D%3D?line=0'>1</a> pinn.trivial_killer_weight = 0.
#       <a href='vscode-notebook-cell:/home/dim1112/Desktop/PINN_prototype/Damped_oscillator.ipynb#W5sZmlsZQ%3D%3D?line=1'>2</a> optimizer_ADAM.lr = 0.000005
# ----> <a href='vscode-notebook-cell:/home/dim1112/Desktop/PINN_prototype/Damped_oscillator.ipynb#W5sZmlsZQ%3D%3D?line=3'>4</a> hist = pinn.fit(num_epochs=500,
#       <a href='vscode-notebook-cell:/home/dim1112/Desktop/PINN_prototype/Damped_oscillator.ipynb#W5sZmlsZQ%3D%3D?line=4'>5</a>                 optimizer=optimizer_LBFGS,
#       <a href='vscode-notebook-cell:/home/dim1112/Desktop/PINN_prototype/Damped_oscillator.ipynb#W5sZmlsZQ%3D%3D?line=5'>6</a>                 verbose=True)
#
# /home/dim1112/Desktop/PINN_prototype/Damped_oscillator.ipynb Cell 6 line 2
#     <a href='vscode-notebook-cell:/home/dim1112/Desktop/PINN_prototype/Damped_oscillator.ipynb#W5sZmlsZQ%3D%3D?line=203'>204</a>             history.append(loss.item())
#     <a href='vscode-notebook-cell:/home/dim1112/Desktop/PINN_prototype/Damped_oscillator.ipynb#W5sZmlsZQ%3D%3D?line=204'>205</a>             return loss
# --> <a href='vscode-notebook-cell:/home/dim1112/Desktop/PINN_prototype/Damped_oscillator.ipynb#W5sZmlsZQ%3D%3D?line=206'>207</a>         optimizer.step(closure=closure)
#     <a href='vscode-notebook-cell:/home/dim1112/Desktop/PINN_prototype/Damped_oscillator.ipynb#W5sZmlsZQ%3D%3D?line=208'>209</a> print('Final Loss: ', history[-1])
#     <a href='vscode-notebook-cell:/home/dim1112/Desktop/PINN_prototype/Damped_oscillator.ipynb#W5sZmlsZQ%3D%3D?line=210'>211</a> return history
#
# File ~/.conda/envs/PyTorch/lib/python3.11/site-packages/torch/optim/optimizer.py:280, in Optimizer.profile_hook_step.<locals>.wrapper(*args, **kwargs)
#     276         else:
#     277             raise RuntimeError(f"{func} must return None or a tuple of (new_args, new_kwargs),"
#     278                                f"but got {result}.")
# --> 280 out = func(*args, **kwargs)
#     281 self._optimizer_step_code()
#     283 # call optimizer step post hooks
#
# File ~/.conda/envs/PyTorch/lib/python3.11/site-packages/torch/utils/_contextlib.py:115, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     112 @functools.wraps(func)
#     113 def decorate_context(*args, **kwargs):
#     114     with ctx_factory():
# --> 115         return func(*args, **kwargs)
#
# File ~/.conda/envs/PyTorch/lib/python3.11/site-packages/torch/optim/lbfgs.py:426, in LBFGS.step(self, closure)
#     423     def obj_func(x, t, d):
#     424         return self._directional_evaluate(closure, x, t, d)
# --> 426     loss, flat_grad, t, ls_func_evals = _strong_wolfe(
#     427         obj_func, x_init, t, d, loss, flat_grad, gtd)
#     428 self._add_grad(t, d)
#     429 opt_cond = flat_grad.abs().max() <= tolerance_grad
#
# File ~/.conda/envs/PyTorch/lib/python3.11/site-packages/torch/optim/lbfgs.py:99, in _strong_wolfe(obj_func, x, t, d, f, g, gtd, c1, c2, tolerance_change, max_ls)
#      97 g_prev = g_new.clone(memory_format=torch.contiguous_format)
#      98 gtd_prev = gtd_new
# ---> 99 f_new, g_new = obj_func(x, t, d)
#     100 ls_func_evals += 1
#     101 gtd_new = g_new.dot(d)
#
# File ~/.conda/envs/PyTorch/lib/python3.11/site-packages/torch/optim/lbfgs.py:424, in LBFGS.step.<locals>.obj_func(x, t, d)
#     423 def obj_func(x, t, d):
# --> 424     return self._directional_evaluate(closure, x, t, d)
#
# File ~/.conda/envs/PyTorch/lib/python3.11/site-packages/torch/optim/lbfgs.py:278, in LBFGS._directional_evaluate(self, closure, x, t, d)
#     276 def _directional_evaluate(self, closure, x, t, d):
#     277     self._add_grad(t, d)
# --> 278     loss = float(closure())
#     279     flat_grad = self._gather_flat_grad()
#     280     self._set_param(x)
#
# File ~/.conda/envs/PyTorch/lib/python3.11/site-packages/torch/utils/_contextlib.py:115, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     112 @functools.wraps(func)
#     113 def decorate_context(*args, **kwargs):
#     114     with ctx_factory():
# --> 115         return func(*args, **kwargs)
#
# /home/dim1112/Desktop/PINN_prototype/Damped_oscillator.ipynb Cell 6 line 2
#     <a href='vscode-notebook-cell:/home/dim1112/Desktop/PINN_prototype/Damped_oscillator.ipynb#W5sZmlsZQ%3D%3D?line=199'>200</a> optimizer.zero_grad()
#     <a href='vscode-notebook-cell:/home/dim1112/Desktop/PINN_prototype/Damped_oscillator.ipynb#W5sZmlsZQ%3D%3D?line=200'>201</a> loss = self.compute_loss(inp_train_int ,verbose=verbose)
# --> <a href='vscode-notebook-cell:/home/dim1112/Desktop/PINN_prototype/Damped_oscillator.ipynb#W5sZmlsZQ%3D%3D?line=201'>202</a> loss.backward()
#     <a href='vscode-notebook-cell:/home/dim1112/Desktop/PINN_prototype/Damped_oscillator.ipynb#W5sZmlsZQ%3D%3D?line=203'>204</a> history.append(loss.item())
#     <a href='vscode-notebook-cell:/home/dim1112/Desktop/PINN_prototype/Damped_oscillator.ipynb#W5sZmlsZQ%3D%3D?line=204'>205</a> return loss
#
# File ~/.conda/envs/PyTorch/lib/python3.11/site-packages/torch/_tensor.py:487, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     477 if has_torch_function_unary(self):
#     478     return handle_torch_function(
#     479         Tensor.backward,
#     480         (self,),
#    (...)
#     485         inputs=inputs,
#     486     )
# --> 487 torch.autograd.backward(
#     488     self, gradient, retain_graph, create_graph, inputs=inputs
#     489 )
#
# File ~/.conda/envs/PyTorch/lib/python3.11/site-packages/torch/autograd/__init__.py:200, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     195     retain_graph = create_graph
#     197 # The reason we repeat same the comment below is that
#     198 # some Python versions print out the first line of a multi-line function
#     199 # calls in the traceback and some print out the last line
# --> 200 Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     201     tensors, grad_tensors_, retain_graph, create_graph, inputs,
#     202     allow_unreachable=True, accumulate_grad=True)
#
# KeyboardInterrupt:

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(y=hist))
# set dark theme
fig.update_layout(title='Loss function', xaxis_title='Epoch', yaxis_title='Loss', template='plotly_dark')
fig.show()

# %%
inputs = pinn.soboleng.draw(1000)
inputs = pinn.convert(inputs)
output = pinn.approximate_solution(inputs)
fig = go.Figure()
fig.add_trace(go.Scatter(x=inputs.detach().numpy()[:,0], y=output.detach().numpy()[:,0], mode='markers', marker=dict(color="red"), name='PINN solution'))
fig.add_trace(go.Scatter(x=inputs.detach().numpy()[:,0], y=5*torch.cos(inputs[:,0]).detach().numpy(), mode='markers', marker=dict(color="lime",size=3), name='Exact solution'))
fig.update_layout(title='Exact solution vs PINN solution', xaxis_title='time', yaxis_title='position', template='plotly_dark')
fig.show()

# %%
# print initial velocity and position
init_t = torch.zeros(1)
pred_init_position = pinn.initial_position(init_t)
pred_init_velocity = pinn.initial_velocity(init_t)
print("Initial position: ", pred_init_position.item())
print("Initial velocity: ", pred_init_velocity.item())
# Out:
# Initial position:  4.989751815795898
# Initial velocity:  -5.529634654521942e-05

# %%
print("Mean square error: ", np.mean((output.detach().numpy()[:,0]*torch.cos(inputs[:,0]).detach().numpy())**2))
# Out:
# Mean square error:  9.472619
